# %%
import pickle
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib notebook

# %%
with open("traj.pkl", "rb") as f:
    dat = pickle.load(f)

# %%
dat
# Out:
# []

# %%
print(x)
# Out:
# [[     0.        ]
#  [-20115.        ]
#  [-20115.        ]
#  ...
#  [-20002.99023438]
#  [-19998.01171875]
#  [-19993.28125   ]]

# %%
import numpy as np
dat_np = np.array(dat)

print(min(dat_np[:, 4]))
# Out:
# 0.0

# %%
dat_np.shape
# Out:
# (4494, 8)

# %%
from sklearn.preprocessing import StandardScaler

scaler_x = StandardScaler()
scaler_y = StandardScaler()
scaler_z = StandardScaler()

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')
x = scaler_x.fit_transform(dat_np[:, 0].reshape(-1, 1))
y = scaler_y.fit_transform(dat_np[:, 1].reshape(-1, 1))
z = scaler_z.fit_transform(dat_np[:, 2].reshape(-1, 1))
ax.scatter(z, y, x , c=list(range(len(dat_np))))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
plt.figure()
plt.plot(z, list(range(len(z))))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-5691da8247c0> in <module>
#       1 plt.figure()
# ----> 2 plt.plot(z, list(range(len(z))))
#       3 plt.show()
#
# TypeError: object of type 'MinMaxScaler' has no len()

# %%
plt.figure()
plt.plot(y, list(range(len(y))))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="672">

# %%
plt.figure()
plt.plot(list(range(len(x))), x )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

fig = go.Figure(data=go.Scatter3d(
    x=x, y=y, z=z
))

fig.update_layout(
    width=800,
    height=700,
    autosize=False,
    scene=dict(
        camera=dict(
            up=dict(
                x=0,
                y=0,
                z=1
            ),
            eye=dict(
                x=0,
                y=1.0707,
                z=1,
            )
        ),
        aspectratio = dict( x=1, y=1, z=0.7 ),
        aspectmode = 'manual'
    ),
)

fig.show()
# Out:
# <div>                            <div id="fc70891b-b126-42e5-b7f4-dcf4629bb094" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc70891b-b126-42e5-b7f4-dcf4629bb094")) {                    Plotly.newPlot(                        "fc70891b-b126-42e5-b7f4-dcf4629bb094",                        [{"type": "scatter3d", "x": [[0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102], [0.5298543412467102]
# ...

# %%
with open("player_data.pkl", "rb") as f:
    dat = pickle.load(f)

# %%
len(dat)
# Out:
# 5502

# %%
items = np.array([[x[0], x[2]] for x in dat if x[1] == "state_flags"])

# %%
items
# Out:
# array([[1651162587961204000,                   1],
#        [1651162584329460000,                   5],
#        [1651162577823263000,                   1]])

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
scal = StandardScaler()
times = scal.fit_transform(items[:, 0].reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-d9e23b5d5f3b> in <module>
#       2 from sklearn.preprocessing import StandardScaler
#       3 scal = StandardScaler()
# ----> 4 times = scal.fit_transform(items[:, 0].reshape(-1, 1))
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
items[:, 1]
# Out:
# array([ 7, 14,  7,  0,  7, 14,  7, 14,  7, 14,  7, 14,  7, 14,  7,  0,  7,
#         0,  7,  0,  7, 14,  7, 14,  7, 14,  7, 14,  7,  0,  7, 14,  7, 14,
#         7])

# %%
plt.stem(times, items[:, 1])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-26-63635747623f>:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(times, items[:, 1])
# <StemContainer object of 3 artists>

# %%
a = 0x903AC310

# %%
hex(0x903AC310 + 0x3C)
# Out:
# '0x903ac34c'

# %%
hex(0x903AC35B-0x903AC310)
# Out:
# '0x4b'

# %%
import numpy as np
with open("player_data.pkl", "rb") as f:
    dat = pickle.load(f)

# %%
items = np.array([[x[0], x[2]] for x in dat if x[1] == "xpos"])

# %%
len(items)
# Out:
# 1556

# %%
x = np.array([[x[0], x[2]] for x in dat if x[1] == "xpos"])
y = np.array([[x[0], x[2]] for x in dat if x[1] == "ypos"])
z = np.array([[x[0], x[2]] for x in dat if x[1] == "zpos"])

# %%
plt.scatter(x, y, z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-cf5e257be3d4> in <module>
# ----> 1 plt.scatter(x, y, z)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2809         verts=cbook.deprecation._deprecated_parameter,
#    2810         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2811     __ret = gca().scatter(
#    2812         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2813         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
x.shape
# Out:
# (1556, 2)

# %%
y.shape
# Out:
# (1642, 2)

# %%
z.shape
# Out:
# (1621, 2)

# %%
plt.figure()
plt.plot(x)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(x[:, 0], (x[:, 1] / max(x[:, 1]))
plt.plot(y[:, 0], y[:, 1] / max(y[:, 1]))
plt.plot(z[:, 0], z[:, 1] / max(z[:, 1]))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lt = 5.1
lt_ = 2.1

print(((3.1 - 5) / 5) * 10)
print(((6.1 - 5) / 5) * 10)
# Out:
# -3.8
# 2.1999999999999993

# %%
MAX_RACETIME = 5
abs(min((6 - MAX_RACETIME) / MAX_RACETIME, 0) * 10)
# Out:
# 0

# %%
lap_times = [2.2, 1.3, 4.5]


[abs(min((lt - MAX_RACETIME) / MAX_RACETIME, 0) * 10) for lt in lap_times]
# Out:
# [5.6, 7.4, 1.0]
